# %%
from flask import Flask,jsonify, request
from flask_cors import CORS, cross_origin
import Smartmodel
app = Flask(__name__)
cors = CORS(app)
app.config['CORS_HEADERS'] = 'application/json'

@app.route("/predict", methods=["POST"])
@cross_origin(supports_credentials=True)
def predictOap():
    data = request.get_json()
    print(data)
    return jsonify(Smartmodel.predict([data]).tolist())

if __name__ == '__main__':
    app.run(debug=True,use_reloader=False)
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: on
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [23/Jun/2023 10:31:42] "OPTIONS /predict HTTP/1.1" 200 -
# {'slNo': 16, 'customerOrderId': 817778366, 'salesOrg': 2493, 'distributionChannel': 'Brazil', 'division': 'South-Region', 'releasedCreditValue': 0, 'purchaseOrderType': 'N241', 'companyCode': 3290, 'orderCreationDate': '02-01-2022', 'orderCreationTime': '133014', 'creditControlArea': 'NR01', 'soldToParty': 964477588, 'orderAmount': 545.85, 'requestedDeliveryDate': '07-01-2022', 'orderCurrency': 'EUR', 'creditStatus': '64', 'customerNumber': 1210182228, 'amountInUSD': 619.28502, 'uniqueCustId': 12101822283290}
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:100: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_amount_removed_3 = df.groupby('unique_cust_id').apply(lambda x: removeOutlier(x, 'amount_in_usd'))
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:165: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df[n] = getattr(fld.dt,n.lower())
# 127.0.0.1 - - [23/Jun/2023 10:31:47] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Jun/2023 10:32:16] "OPTIONS /predict HTTP/1.1" 200 -
# {'slNo': 56, 'customerOrderId': 778638920, 'salesOrg': 2373, 'distributionChannel': 'Thailand', 'division': 'South-Region', 'releasedCreditValue': 0, 'purchaseOrderType': 'DFUE', 'companyCode': 3350, 'orderCreationDate': '01-01-2022', 'orderCreationTime': '60015', 'creditControlArea': 'NR01', 'soldToParty': 815559921, 'orderAmount': 0, 'requestedDeliveryDate': '03-01-2022', 'orderCurrency': 'EUR', 'creditStatus': '', 'customerNumber': 1230010772, 'amountInUSD': 0, 'uniqueCustId': 12300107723350}
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:100: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_amount_removed_3 = df.groupby('unique_cust_id').apply(lambda x: removeOutlier(x, 'amount_in_usd'))
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:165: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df[n] = getattr(fld.dt,n.lower())
# 127.0.0.1 - - [23/Jun/2023 10:32:17] "POST /predict HTTP/1.1" 200 -
# {'slNo': 56, 'customerOrderId': 778638920, 'salesOrg': 2373, 'distributionChannel': 'Thailand', 'division': 'South-Region', 'releasedCreditValue': 0, 'purchaseOrderType': 'DFUE', 'companyCode': 3350, 'orderCreationDate': '01-01-2022', 'orderCreationTime': '60015', 'creditControlArea': 'NR01', 'soldToParty': 815559921, 'orderAmount': 1318.3852379781997, 'requestedDeliveryDate': '03-01-2022', 'orderCurrency': 'EUR', 'creditStatus': '', 'customerNumber': 1230010772, 'amountInUSD': 0, 'uniqueCustId': 12300107723350}
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:100: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_amount_removed_3 = df.groupby('unique_cust_id').apply(lambda x: removeOutlier(x, 'amount_in_usd'))
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:165: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df[n] = getattr(fld.dt,n.lower())
# 127.0.0.1 - - [23/Jun/2023 10:32:21] "POST /predict HTTP/1.1" 200 -
# 127.0.0.1 - - [23/Jun/2023 12:00:08] "OPTIONS /predict HTTP/1.1" 200 -
# {'slNo': 4, 'customerOrderId': 930253442, 'salesOrg': 2381, 'distributionChannel': 'Greece', 'division': 'South-Region', 'releasedCreditValue': 0, 'purchaseOrderType': 'N000', 'companyCode': 3290, 'orderCreationDate': '01-01-2022', 'orderCreationTime': '160020', 'creditControlArea': 'SR01', 'soldToParty': 947942786, 'orderAmount': 0, 'requestedDeliveryDate': '06-01-2022', 'orderCurrency': 'EUR', 'creditStatus': '64', 'customerNumber': 1210351400, 'amountInUSD': 0, 'uniqueCustId': 12103514003290}
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:100: FutureWarning: Not prepending group keys to the result index of transform-like apply. In the future, the group keys will be included in the index, regardless of whether the applied function returns a like-indexed object.
# To preserve the previous behavior, use
#
# 	>>> .groupby(..., group_keys=False)
#
# To adopt the future behavior and silence this warning, use
#
# 	>>> .groupby(..., group_keys=True)
#   df_amount_removed_3 = df.groupby('unique_cust_id').apply(lambda x: removeOutlier(x, 'amount_in_usd'))
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   melt['Last-'+str(i)+'day_Sales'] = melt.groupby([customer_id_col])[net_amount_col].shift(i)
# C:\Users\KIIT\OneDrive\Documents\HighRadius\Frontend\React JS\milestone-6\Flask\H2H Flask\Smartmodel.py:165: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df[n] = getattr(fld.dt,n.lower())
# 127.0.0.1 - - [23/Jun/2023 12:00:09] "POST /predict HTTP/1.1" 200 -

# %%
pip install flask_cors
# Out:
# Collecting flask_corsNote: you may need to restart the kernel to use updated packages.
#   Downloading Flask_Cors-3.0.10-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: Six in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from flask_cors) (1.16.0)
# Requirement already satisfied: Flask>=0.9 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from flask_cors) (2.2.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from Flask>=0.9->flask_cors) (6.0.1)
# Requirement already satisfied: Jinja2>=3.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from Flask>=0.9->flask_cors) (3.0.3)
# Requirement already satisfied: itsdangerous>=2.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from Flask>=0.9->flask_cors) (2.1.2)
# Requirement already satisfied: Werkzeug>=2.2.2 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from Flask>=0.9->flask_cors) (2.2.2)
# Requirement already satisfied: click>=8.0 in c:\users\kiit\appdata\roaming\python\python39\site-packages (from Flask>=0.9->flask_cors) (8.1.3)
# Requirement already satisfied: colorama in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from click>=8.0->Flask>=0.9->flask_cors) (0.4.5)
# Requirement already satisfied: zipp>=0.5 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from importlib-metadata>=3.6.0->Flask>=0.9->flask_cors) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from Jinja2>=3.0->Flask>=0.9->flask_cors) (2.1.1)
# Installing collected packages: flask-cors
# Successfully installed flask-cors-3.0.10

# %%
# Out:
# Collecting currency_converter
#   Downloading currency.converter-0.5.5.tar.gz (53 kB)
# Requirement already satisfied: setuptools in c:\users\kiit\anaconda3\lib\site-packages (from currency_converter) (61.2.0)
# Building wheels for collected packages: currency-converter
#   Building wheel for currency-converter (setup.py): started
#   Building wheel for currency-converter (setup.py): finished with status 'done'
#   Created wheel for currency-converter: filename=currency.converter-0.5.5-py3-none-any.whl size=65942 sha256=65b169157199f819bf3253edcb37c169fd66b45c3a048e2fe8182be440efe2b6
#   Stored in directory: c:\users\kiit\appdata\local\pip\cache\wheels\32\17\bd\35d81cc2e6834b1e0f7fa273e667b71933a92b2360e76ac30d
# Successfully built currency-converter
# Installing collected packages: currency-converter
# Successfully installed currency-converter-0.5.5
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install lightgbm
# Out:
# Collecting lightgbm
#   Using cached lightgbm-3.3.5-py3-none-win_amd64.whl (1.0 MB)
# Requirement already satisfied: scipy in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from lightgbm) (1.7.3)
# Requirement already satisfied: wheel in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from lightgbm) (0.35.1)
# Requirement already satisfied: numpy in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from lightgbm) (1.22.3)
# Requirement already satisfied: scikit-learn!=0.22.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from lightgbm) (1.1.2)
# Requirement already satisfied: joblib>=1.0.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\kiit\anaconda3\envs\ev_2\lib\site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5
# Note: you may need to restart the kernel to use updated packages.
